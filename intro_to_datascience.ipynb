# %%
#libraries for analysis

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('http://bit.ly/FinancialDataset')
# df.head()
# df.tail(10)
# df.info()

# df.shape
# df.columns
# df.describe()
# df.dtypes

# df['Cell Phone Access'].nunique()
# df['The relathip with head'].unique()


#plotting a histogram using matplotlib and seaborn

df.dropna(inplace = True)


plt.figure(figsize = (8, 5))
sns.distplot(df['Respondent Age'], color = 'maroon')
plt.title('Histogram for Respondent Age')
plt.xlabel('Respondent Age')
plt.ylabel('Frequency')
plt.show()

# %%
# df['Respondent Age'].skew()

# plt.figure(figsize = (8,5))
# sns.countplot(df['country'])
# plt.title('Country Bar Graph',color = 'red', fontdict = {'size':20})

# plt.show()


plt.figure(figsize = (8,5))
sns.countplot(df['marital_status'])
plt.show()
